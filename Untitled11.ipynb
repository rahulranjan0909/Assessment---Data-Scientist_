# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulranjan0909/Assessment---Data-Scientist_/blob/master/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
data=pd.read_csv("/content/ts_model_sample_data.csv")

# %%
data["InvoiceDate"]=pd.to_datetime(data["InvoiceDate"])

# %%
from types import MethodType
data["Description"]=data["Description"].fillna("mode")

# %%
data["Quantity"]=abs(data["Quantity"])

# %%
data["Customer ID"]=data["Customer ID"].fillna("mode")

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
data.shape
# Out:
# (1067371, 8)

# %%
(318268-67076)/318268
# Out:
# 0.7892467982957759

# %%
data["Total"]=data["Quantity"]*data["Price"]

# %%
data.set_index("InvoiceDate",inplace=True)

# %%
data["Day_of_week"]=data.index.weekday

# %%
data.head(20)
# Out:
#                     Invoice StockCode                          Description  \
# InvoiceDate
# 2009-12-01 07:45:00  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 2009-12-01 07:45:00  489434    79323P                   PINK CHERRY LIGHTS
# 2009-12-01 07:45:00  489434    79323W                  WHITE CHERRY LIGHTS
# 2009-12-01 07:45:00  489434     22041         RECORD FRAME 7" SINGLE SIZE
# 2009-12-01 07:45:00  489434     21232       STRAWBERRY CERAMIC TRINKET BOX
# 2009-12-01 07:45:00  489434     22064           PINK DOUGHNUT TRINKET POT
# 2009-12-01 07:45:00  489434     21871                  SAVE THE PLANET MUG
# 2009-12-01 07:45:00  489434     21523   FANCY FONT HOME SWEET HOME DOORMAT
# 2009-12-01 07:46:00  489435     22350                            CAT BOWL
# 2009-12-01 07:46:00  489435     22349       DOG BOWL , CHASING BALL DESIGN
# 2009-12-01 07:46:00  489435     22195         HEART MEASURING SPOONS LARGE
# ...

# %%
data.groupby("Customer ID","")["Total"].sum().reset_index()
# Out:
#       Customer ID    Total
# 0         12346.0   804.90
# 1         12349.0  1292.67
# 2         12355.0   488.21
# 3         12358.0  1697.93
# 4         12359.0  2106.03
# ...           ...      ...
# 3362      18281.0   120.32
# 3363      18283.0   446.42
# 3364      18285.0   427.00
# 3365      18286.0  1404.43
# 3366      18287.0  1076.71
#
# [3367 rows x 2 columns]
